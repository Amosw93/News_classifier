# %% [markdown]
# Prepare dataset for news ML classifier.

# %% [markdown]
# # Extract news articles from the path

# %%
import pandas as pd

# %%
# Access the google drive account
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Set up Goggle drive folder path
busi_path = '/content/drive/MyDrive/Colab Notebooks/News_articles/business_articles.xlsx'
clim_path = '/content/drive/MyDrive/Colab Notebooks/News_articles/climate_change_articles.xlsx'
pol_path = '/content/drive/MyDrive/Colab Notebooks/News_articles/politics_articles.xlsx'
tech_path = '/content/drive/MyDrive/Colab Notebooks/News_articles/tech_articles.xlsx'
wld_path = '/content/drive/MyDrive/Colab Notebooks/News_articles/world_articles.xlsx'

# %%
# Read the excel file from the google drive for news articles
busi_art = pd.read_excel(busi_path)
clim_art = pd.read_excel(clim_path)
pol_art = pd.read_excel(pol_path)
tech_art = pd.read_excel(tech_path)
wld_art = pd.read_excel(wld_path)

# %%
# Add category column to each dataframe
busi_df = busi_art
busi_df['category'] = 'business'

clim_df = clim_art
clim_df['category'] = 'climate change'

pol_df = pol_art
pol_df["category"] = 'politics'

tech_df = tech_art
tech_df["category"] = 'technology'

wld_df = wld_art
wld_df["category"] = 'world'

# %% [markdown]
# # Expore the news articles based on their category

# %%
busi_df.columns
# Out:
# Index(['uri', 'lang', 'isDuplicate', 'date', 'time', 'dateTime', 'dateTimePub',
#        'dataType', 'sim', 'url', 'title', 'body', 'source', 'authors', 'image',
#        'eventUri', 'sentiment', 'wgt', 'relevance', 'sourceTitle', 'sourceUri',
#        'category'],
#       dtype='object')

# %% [markdown]
# ## Explore business news articles

# %%
busi_df.loc[0:3, ["title", "body", "category", "sourceTitle"]]
# Out:
#                                                title  \
# 0  Can China’s loan rule ‘trick’ help grease the ...
# 1  State power: Xi calls for firmer government ha...
# 2  How to fix China’s economy? Investors are unsu...
# 3  China spins up new party finance organ as prop...
#
#                                                 body  category  \
# 0  National Administration of Financial Regulatio...  business
# 1  To ensure stability and security in decisive s...  business
# 2  Investor sentiment around China’s prospects ha...  business
# 3  New commission, which began operations last mo...  business
#
#                 sourceTitle
# 0  South China Morning Post
# 1  South China Morning Post
# 2  South China Morning Post
# 3  South China Morning Post

# %% [markdown]
# ## Explore climate change news articles

# %%
clim_df.loc[3:6, ["title", "body", "category", "sourceTitle"]]
# Out:
#                                                title  \
# 3  UN chief tells world to 'get a grip' as report...
# 4  UN chief calls for an "ambition supernova" as ...
# 5  Worsening warming is hurting people in all reg...
# 6  Italy's extreme drought mirrors climate in Eth...
#
#                                                 body        category  \
# 3  Governments' plans to limit climate change to ...  climate change
# 4  Countries´ climate action plans are still far ...  climate change
# 5  Revved-up climate change now permeates America...  climate change
# 6  Climate change is causing "hazard flips", wher...  climate change
#
#          sourceTitle
# 3           Sky News
# 4  Daily Mail Online
# 5  Daily Mail Online
# 6           Sky News

# %% [markdown]
# ## Explore politics news articles

# %%
pol_df.loc[10:13, ["title", "body", "category", "sourceTitle"]]
# Out:
#                                                 title  \
# 10            Lee Atwater, Tough Ex-Head of GOP, Dies
# 11  Opinion | This Is How the Republican Party Got...
# 12                    Confessions of a Brexit fanatic
# 13  What? Where? When? A Brainy Russian Quiz Show ...
#
#                                                  body  category  \
# 10  Former Republican National Chairman Lee Atwate...  politics
# 11  In 1969, a young aide in the Nixon White House...  politics
# 12  {{ #verifyErrors }}{{ message }}{{ /verifyErro...  politics
# 13  It's been on Russia's airwaves since the Sovie...  politics
#
#                      sourceTitle
# 10             Los Angeles Times
# 11            The New York Times
# 12               The Independent
# 13  RadioFreeEurope/RadioLiberty

# %% [markdown]
# ## Explore technology news articles

# %%
tech_df.loc[20:23, ["title", "body", "category", "sourceTitle"]]
# Out:
#                                                 title  \
# 20  Tech Start-Ups Try to Sell a Cautious Pentagon...
# 21  ANDREA MIOTTI: Leaders must resist siren calls...
# 22  The fight against fake photos: How Adobe is em...
# 23  Wednesday briefing: Inside the battle to conta...
#
#                                                  body    category  \
# 20  Reporting from Devils Lake, N.D., Denver and W...  technology
# 21  As I write, Silicon Valley tech leaders are fl...  technology
# 22  A lawsuit filed by three visual artists agains...  technology
# 23  In today's newsletter: As Rishi Sunak gets rea...  technology
#
#            sourceTitle
# 20  The New York Times
# 21   Daily Mail Online
# 22           USA Today
# 23        The Guardian

# %% [markdown]
# ## Explore world news articles

# %%
wld_df.loc[34:37, ["title", "body", "category", "sourceTitle"]]
# Out:
#                                                 title  \
# 34  China tells UK to stop using trade to improve ...
# 35  Turkey is marking its centennial. But a brain ...
# 36  Fortune 500 Europe: Which company is the bigge...
# 37  Go off-piste in Europe at these 13 wild skiing...
#
#                                                  body category  \
# 34  UK and Taiwan sign trade agreement they hailed...    world
# 35  ISTANBUL (AP) - Huseyin Buyukdag says he loves...    world
# 36  Introducing a new ranking of Europe's ever-cha...    world
# 37  From Albania to Poland, Europe has an abundanc...    world
#
#           sourceTitle
# 34       The Guardian
# 35  Daily Mail Online
# 36   Euronews English
# 37   Euronews English

# %% [markdown]
# # Combine each news category as a single dataset

# %%
news_art_df = pd.concat([busi_df,
                         clim_df,
                         pol_df,
                         tech_df,
                         wld_df],
                        axis = 0, ignore_index = True)

# %%
news_art_df.head()
# Out:
#           uri lang  isDuplicate        date      time              dateTime  \
# 0  7816062173  eng        False  2023-11-03  09:25:06  2023-11-03T09:25:06Z
# 1  7824577130  eng        False  2023-11-08  12:02:20  2023-11-08T12:02:20Z
# 2  7814197764  eng        False  2023-11-02  09:01:43  2023-11-02T09:01:43Z
# 3  7783150762  eng        False  2023-10-13  22:02:16  2023-10-13T22:02:16Z
# 4  7825182017  eng        False  2023-11-08  18:06:38  2023-11-08T18:06:38Z
#
#             dateTimePub dataType       sim  \
# 0  2023-11-03T09:24:15Z     news  0.552941
# 1  2023-11-08T12:00:30Z     news  0.000000
# 2  2023-11-02T09:00:21Z     news  0.000000
# 3  2023-10-13T22:00:08Z     news  0.000000
# 4  2023-11-08T17:54:52Z     news  0.792157
#
#                                                  url  ...  \
# 0  https://www.scmp.com/economy/china-economy/art...  ...
# 1  https://www.scmp.com/economy/china-economy/art...  ...
# 2  https://www.scmp.com/comment/opinion/article/3...  ...
# 3  https://www.scmp.com/economy/china-economy/art...  ...
# 4  https://www.dailymail.co.uk/wires/ap/article-1...  ...
#
#                                               source authors  \
# 0  {'uri': 'scmp.com', 'dataType': 'news', 'title...      []
# 1  {'uri': 'scmp.com', 'dataType': 'news', 'title...      []
# 2  {'uri': 'scmp.com', 'dataType': 'news', 'title...      []
# 3  {'uri': 'scmp.com', 'dataType': 'news', 'title...      []
# 4  {'uri': 'dailymail.co.uk', 'dataType': 'news',...      []
#
#                                                image     eventUri sentiment  \
# 0  https://cdn.i-scmp.com/sites/default/files/sty...  eng-9028689       NaN
# 1  https://cdn.i-scmp.com/sites/default/files/sty...          NaN  0.270588
# 2  https://cdn.i-scmp.com/sites/default/files/sty...          NaN  0.098039
# 3  https://cdn.i-scmp.com/sites/default/files/sty...          NaN  0.184314
# 4  https://i.dailymail.co.uk/1s/2023/11/08/17/wir...  eng-9042157       NaN
#
#    wgt  relevance               sourceTitle        sourceUri  category
# 0  100        100  South China Morning Post         scmp.com  business
# 1   76         76  South China Morning Post         scmp.com  business
# 2   76         76  South China Morning Post         scmp.com  business
# 3   76         76  South China Morning Post         scmp.com  business
# 4   51         51         Daily Mail Online  dailymail.co.uk  business
#
# [5 rows x 22 columns]

# %%
news_art_df.tail()
# Out:
#               uri lang  isDuplicate        date      time  \
# 15773  7818994285  eng        False  2023-11-05  08:29:55
# 15774  7818990653  eng        False  2023-11-05  08:27:12
# 15775  7818984582  eng        False  2023-11-05  08:21:56
# 15776  7818983414  eng        False  2023-11-05  08:19:26
# 15777  7818935168  eng        False  2023-11-05  07:32:50
#
#                    dateTime           dateTimePub dataType       sim  \
# 15773  2023-11-05T08:29:55Z  2023-11-05T08:22:43Z     news  0.658824
# 15774  2023-11-05T08:27:12Z  2023-11-05T08:19:59Z     news  0.768627
# 15775  2023-11-05T08:21:56Z  2023-11-05T08:09:12Z     news  0.705882
# 15776  2023-11-05T08:19:26Z  2023-11-05T08:18:53Z     news  0.000000
# 15777  2023-11-05T07:32:50Z  2023-11-05T07:30:35Z     news  0.878431
#
#                                                      url  ...  \
# 15773  https://www.rferl.org/a/moldova-local-election...  ...
# 15774  https://www.theguardian.com/world/live/2023/no...  ...
# 15775  https://www.dailymail.co.uk/wires/ap/article-1...  ...
# 15776  https://www.scmp.com/lifestyle/arts-culture/ar...  ...
# 15777  https://www.euronews.com/2023/11/05/war-in-ukr...  ...
#
#                                                   source  \
# 15773  {'uri': 'rferl.org', 'dataType': 'news', 'titl...
# 15774  {'uri': 'theguardian.com', 'dataType': 'news',...
# 15775  {'uri': 'dailymail.co.uk', 'dataType': 'news',...
# 15776  {'uri': 'scmp.com', 'dataType': 'news', 'title...
# 15777  {'uri': 'euronews.com', 'dataType': 'news', 't...
#
#                                                  authors  \
# 15773                                                 []
# 15774  [{'uri': 'jem_bartholomew@theguardian.com', 'n...
# 15775                                                 []
# 15776                                                 []
# 15777                                                 []
#
#                                                    image     eventUri  \
# 15773  https://gdb.rferl.org/5C1DE69C-336E-4163-B8A8-...  eng-9026106
# 15774  https://i.guim.co.uk/img/media/64c03ff6abc8688...  eng-9033413
# 15775                                                NaN  eng-9026106
# 15776                                                NaN          NaN
# 15777  https://static.euronews.com/articles/stories/0...  eng-9032512
#
#       sentiment  wgt  relevance                   sourceTitle  \
# 15773       NaN  100        100  RadioFreeEurope/RadioLiberty
# 15774 -0.184314  100        100                  The Guardian
# 15775 -0.058824  100        100             Daily Mail Online
# 15776 -0.137255  100        100      South China Morning Post
# 15777 -0.254902  100        100              Euronews English
#
#              sourceUri category
# 15773        rferl.org    world
# 15774  theguardian.com    world
# 15775  dailymail.co.uk    world
# 15776         scmp.com    world
# 15777     euronews.com    world
#
# [5 rows x 22 columns]

# %% [markdown]
# # Cleanning and pre-processing

# %%
news_df = news_art_df[["title", "body", "category"]]

# %%
news_df.head(5)
# Out:
#                                                title  \
# 0  Can China’s loan rule ‘trick’ help grease the ...
# 1  State power: Xi calls for firmer government ha...
# 2  How to fix China’s economy? Investors are unsu...
# 3  China spins up new party finance organ as prop...
# 4  Commercial fishing groups sue 13 US tire maker...
#
#                                                 body  category
# 0  National Administration of Financial Regulatio...  business
# 1  To ensure stability and security in decisive s...  business
# 2  Investor sentiment around China’s prospects ha...  business
# 3  New commission, which began operations last mo...  business
# 4  TACOMA, Wash. (AP) - The 13 largest U.S. tire ...  business

# %% [markdown]
# ## Removing the stopwords.

# %%
import re
from nltk.corpus import stopwords

def standardize_sentences(sentences):

  clean_sentences = []
  stop_words = set(stopwords.words('english'))

  for sentence in sentences:
    lower_text = sentence.lower() # Lowercasing text

    # regular expression for symbols
    reg_exp_text = re.sub('[^a-zA-Z]', ' ', lower_text)

    # remove stopwords
    clean_sentence = ' '.join(word for word in reg_exp_text.split() if word
                               not in stop_words)

    # append clean sentences
    clean_sentences.append(clean_sentence)

  return clean_sentences

# %%
# Extract specific sentences to clean
body = news_df["body"]

# Call the function to standardise the above text
clean_body = standardize_sentences(body)

# %%
news_df['clean_body'] = clean_body
news_df.head(5)
# Out:
# <ipython-input-36-218edd09658f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_df['clean_body'] = clean_body
#                                                title  \
# 0  Can China’s loan rule ‘trick’ help grease the ...
# 1  State power: Xi calls for firmer government ha...
# 2  How to fix China’s economy? Investors are unsu...
# 3  China spins up new party finance organ as prop...
# 4  Commercial fishing groups sue 13 US tire maker...
#
#                                                 body  category  \
# 0  National Administration of Financial Regulatio...  business
# 1  To ensure stability and security in decisive s...  business
# 2  Investor sentiment around China’s prospects ha...  business
# 3  New commission, which began operations last mo...  business
# 4  TACOMA, Wash. (AP) - The 13 largest U.S. tire ...  business
#
#                                           clean_body
# 0  national administration financial regulation l...
# 1  ensure stability security decisive sectors xi ...
# 2  investor sentiment around china prospects rema...
# 3  new commission began operations last month par...
# 4  tacoma wash ap largest u tire manufacturers fa...

# %% [markdown]
# ## Labelling the news category

# %%
from sklearn.preprocessing import LabelEncoder

# Simplified dataframe for ML task
news_ML_df = news_df[["clean_body", "category"]]

# Extract categories
categories = news_ML_df['category']

# Call encoder for labelling the numeric classification
label_encoder = LabelEncoder()

# Covert categort into numeric categories
numeric_cat = label_encoder.fit_transform(categories)

# Mapping original and numeric categories
category_mapping = dict(zip(label_encoder.classes_,
                            label_encoder.transform(label_encoder.classes_)))
mapping_df = pd.DataFrame(list(category_mapping.items()),
                          columns = ['original category',
                                     'numeric category'])

# Replacing the original category
news_ML_df['category'] = numeric_cat
# Out:
# <ipython-input-37-1b8c728f0dbd>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_ML_df['category'] = numeric_cat

# %%
# show the mapping result of the category
print('Show the original categories and their cooresponding numeric \
value:')
print('')
print(mapping_df)
# Out:
# Show the original categories and their cooresponding numeric value:
#
#   original category  numeric category
# 0          business                 0
# 1    climate change                 1
# 2          politics                 2
# 3        technology                 3
# 4             world                 4

# %%
# show the
news_ML_df.head(3)
# Out:
#                                           clean_body  category
# 0  national administration financial regulation l...         0
# 1  ensure stability security decisive sectors xi ...         0
# 2  investor sentiment around china prospects rema...         0

# %% [markdown]
# ## Tokenization

# %% [markdown]
# Next, it will create two columns "tokenized_body" and "freq_tokens".
#
# "tokenized_body" column tokenize all the words from the column "clean_body".
#
# "freq_tokens" column tokenize the most frequent words from the column "clean_body".

# %%
# Tokenize the body
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

nltk.download('punkt')

# Tokenize the body
news_ML_df['tokenized_body'] = news_ML_df['clean_body'].apply(word_tokenize)


# Calculate the frequency of each token
all_tokens = [token for tokens in news_ML_df['tokenized_body'] for
              token in tokens]
freq_dist = FreqDist(all_tokens)

# Define the number of most frequent words for tokenization
n_freq_words = 1000

# Get the most frequent tokens
freq_tokens = set(token for token, freq in freq_dist.most_common(n_freq_words))

# Keep the most frequent tokens
news_ML_df['freq_tokens'] = news_ML_df['tokenized_body'].apply(lambda tokens:
                            [token for token in tokens if token in freq_tokens])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <ipython-input-40-30447fe713da>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_ML_df['tokenized_body'] = news_ML_df['clean_body'].apply(word_tokenize)

# %%
news_ML_df.head(3)
# Out:
#                                           clean_body  category  \
# 0  national administration financial regulation l...         0
# 1  ensure stability security decisive sectors xi ...         0
# 2  investor sentiment around china prospects rema...         0
#
#                                       tokenized_body  \
# 0  [national, administration, financial, regulati...
# 1  [ensure, stability, security, decisive, sector...
# 2  [investor, sentiment, around, china, prospects...
#
#                                          freq_tokens
# 0  [national, administration, financial, risk, ba...
# 1  [ensure, security, xi, state, firms, market, a...
# 2  [around, china, despite, significant, increase...

# %%
tokenized_df = news_ML_df
tokenized_df['freq_tokens'] = tokenized_df['freq_tokens'].apply(' '.join)

# %%
tokenized_df["tokenized_body"] = tokenized_df['tokenized_body'].apply(' '.join)
tokenized_df["tokenized_body"]
# Out:
# 0        national administration financial regulation l...
# 1        ensure stability security decisive sectors xi ...
# 2        investor sentiment around china prospects rema...
# 3        new commission began operations last month par...
# 4        tacoma wash ap largest u tire manufacturers fa...
#                                ...
# 15773    chisinau moldovan voting november elect mayors...
# 15774    russia says one ship damaged ukrainian attack ...
# 15775    chisinau moldova ap moldovans casting ballots ...
# 15776    george orwell library set city ivanovo counter...
# 15777    russian attacks ukraine wounded least civilian...
# Name: tokenized_body, Length: 15778, dtype: object

# %%
# Show the tokenized dataframe
tokenized_df.head()
# Out:
#                                           clean_body  category  \
# 0  national administration financial regulation l...         0
# 1  ensure stability security decisive sectors xi ...         0
# 2  investor sentiment around china prospects rema...         0
# 3  new commission began operations last month par...         0
# 4  tacoma wash ap largest u tire manufacturers fa...         0
#
#                                       tokenized_body  \
# 0  national administration financial regulation l...
# 1  ensure stability security decisive sectors xi ...
# 2  investor sentiment around china prospects rema...
# 3  new commission began operations last month par...
# 4  tacoma wash ap largest u tire manufacturers fa...
#
#                                          freq_tokens
# 0  national administration financial risk banks a...
# 1  ensure security xi state firms market access l...
# 2  around china despite significant increase poli...
# 3  new commission began operations last month par...
# 4  ap largest u facing california could force com...

# %% [markdown]
# ## Vectorization

# %% [markdown]
# Preparing data for a machine learning classifier by converting the
# tokenized body into a numeric value

# %% [markdown]
# ## Create bag of words (BoW)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Extract tokenized text
tokenized_text = tokenized_df["tokenized_body"]

# Create a vectorizer
vectorizer = CountVectorizer()

# Fit and transfrom the tokenized text
X1_count = vectorizer.fit_transform(tokenized_text)

# %%
# Extract the most frequent tokens
freq_tokens_text = tokenized_df["freq_tokens"]

# Fit and transform the most frequent tokens
X2_count = vectorizer.fit_transform(freq_tokens_text)

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()


# Fit and transform the test
X1_tfidf = tfidf_vectorizer.fit_transform(tokenized_text)
X2_tfidf = tfidf_vectorizer.fit_transform(freq_tokens_text)

# %%
import pandas as pd
X1_count_df = pd.DataFrame(X1_count.toarray(), columns = vectorizer.get_feature_names_out())

# %%
vectorised_df = pd.cona
